# %% [markdown]
# # Zillow Clustering Project

# %%
import numpy as np
import pandas as pd
from pandas.api.types import is_numeric_dtype

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import math

import scipy.stats as stats
from scipy.stats import zscore, iqr, percentileofscore, scoreatpercentile

from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

import sklearn.metrics
import sklearn.linear_model
from sklearn.feature_selection import RFE

import wrangle_zillow as wr
import preprocessing as pr
import explore as ex
import evaluate as ev

import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", None)

# %% [markdown]
# # Acquire
# The DataFrame below contains all fields from the `properties_2017` table as well as the descriptive fields from the appropriate tables in the `zillow` database. The data is filtered to only include properties that have a `latitude` and `longitude` value.

# %%
df = wr.get_zillow_data()
print(f"Our DataFrame has {df.shape[0]} rows and {df.shape[1]} columns.")
df.head()
# Out:
# Our DataFrame has 77580 rows and 68 columns.
#         id  parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0  1727539  14297519                    NaN                       NaN
# 1  1387261  17052889                    NaN                       NaN
# 2    11677  14186244                    NaN                       NaN
# 3  2288172  12177905                    NaN                       NaN
# 4  1970746  10887214                    1.0                       NaN
#
#    basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0           NaN          3.5         4.0                  NaN
# 1           NaN          1.0         2.0                  NaN
# 2           NaN          2.0         3.0                  NaN
# 3           NaN          3.0         4.0                  NaN
# 4           NaN          3.0         3.0                  NaN
#
#    buildingqualitytypeid  calculatedbathnbr  decktypeid  \
# 0                    NaN                3.5         NaN
# 1                    NaN                1.0         NaN
# 2                    NaN                2.0         NaN
# 3                    8.0                3.0         NaN
# 4                    8.0                3.0         NaN
#
#    finishedfloor1squarefeet  calculatedfinishedsquarefeet  \
# 0                       NaN                        3100.0
# 1                    1465.0                        1465.0
# 2                       NaN                        1243.0
# 3                       NaN                        2376.0
# 4                       NaN                        1312.0
#
#    finishedsquarefeet12  finishedsquarefeet13  finishedsquarefeet15  \
# 0                3100.0                   NaN                   NaN
# 1                1465.0                   NaN                   NaN
# 2                1243.0                   NaN                   NaN
# 3                2376.0                   NaN                   NaN
# 4                1312.0                   NaN                   NaN
#
#    finishedsquarefeet50  finishedsquarefeet6    fips  fireplacecnt  \
# 0                   NaN                  NaN  6059.0           NaN
# 1                1465.0                  NaN  6111.0           1.0
# 2                   NaN                  NaN  6059.0           NaN
# 3                   NaN                  NaN  6037.0           NaN
# 4                   NaN                  NaN  6037.0           NaN
#
#    fullbathcnt  garagecarcnt  garagetotalsqft  hashottuborspa  \
# 0          3.0           2.0            633.0             NaN
# 1          1.0           1.0              0.0             NaN
# 2          2.0           2.0            440.0             NaN
# 3          3.0           NaN              NaN             NaN
# 4          3.0           NaN              NaN             NaN
#
#    heatingorsystemtypeid    latitude    longitude  lotsizesquarefeet  poolcnt  \
# 0                    NaN  33634931.0 -117869207.0             4506.0      NaN
# 1                    NaN  34449266.0 -119281531.0            12647.0      NaN
# 2                    NaN  33886168.0 -117823170.0             8432.0      1.0
# 3                    2.0  34245180.0 -118240722.0            13038.0      1.0
# 4                    2.0  34185120.0 -118414640.0           278581.0      1.0
#
#    poolsizesum  pooltypeid10  pooltypeid2  pooltypeid7  \
# 0          NaN           NaN          NaN          NaN
# 1          NaN           NaN          NaN          NaN
# 2          NaN           NaN          NaN          1.0
# 3          NaN           NaN          NaN          1.0
# 4          NaN           NaN          NaN          1.0
#
#   propertycountylandusecode  propertylandusetypeid propertyzoningdesc  \
# 0                       122                  261.0                NaN
# 1                      1110                  261.0                NaN
# 2                       122                  261.0                NaN
# 3                      0101                  261.0         LCR110000*
# 4                      010C                  266.0               LAR3
#
#    rawcensustractandblock  regionidcity  regionidcounty  regionidneighborhood  \
# 0            6.059063e+07       53571.0          1286.0                   NaN
# 1            6.111001e+07       13091.0          2061.0                   NaN
# 2            6.059022e+07       21412.0          1286.0                   NaN
# 3            6.037300e+07      396551.0          3101.0                   NaN
# 4            6.037124e+07       12447.0          3101.0              268548.0
#
#    regionidzip  roomcnt  storytypeid  threequarterbathnbr  \
# 0      96978.0      0.0          NaN                  1.0
# 1      97099.0      5.0          NaN                  NaN
# 2      97078.0      6.0          NaN                  NaN
# 3      96330.0      0.0          NaN                  NaN
# 4      96451.0      0.0          NaN                  NaN
#
#    typeconstructiontypeid  unitcnt  yardbuildingsqft17  yardbuildingsqft26  \
# 0                     NaN      NaN                 NaN                 NaN
# 1                     NaN      NaN                 NaN                 NaN
# 2                     NaN      NaN                 NaN                 NaN
# 3                     NaN      1.0                 NaN                 NaN
# 4                     NaN      1.0                 NaN                 NaN
#
#    yearbuilt  numberofstories  fireplaceflag  structuretaxvaluedollarcnt  \
# 0     1998.0              NaN            NaN                    485713.0
# 1     1967.0              1.0            NaN                     88000.0
# 2     1962.0              1.0            NaN                     85289.0
# 3     1970.0              NaN            NaN                    108918.0
# 4     1964.0              NaN            NaN                     73681.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0          1023282.0          2016.0               537569.0   11013.72
# 1           464000.0          2016.0               376000.0    5672.48
# 2           564778.0          2016.0               479489.0    6488.30
# 3           145143.0          2016.0                36225.0    1777.51
# 4           119407.0          2016.0                45726.0    1533.89
#
#   taxdelinquencyflag  taxdelinquencyyear  censustractandblock  logerror  \
# 0                NaN                 NaN         6.059063e+13  0.025595
# 1                NaN                 NaN         6.111001e+13  0.055619
# 2                NaN                 NaN         6.059022e+13  0.005383
# 3                NaN                 NaN         6.037300e+13 -0.103410
# 4                NaN                 NaN         6.037124e+13  0.006940
#
#   transactiondate airconditioningdesc architecturalstyledesc  \
# 0      2017-01-01                 NaN                    NaN
# 1      2017-01-01                 NaN                    NaN
# 2      2017-01-01                 NaN                    NaN
# 3      2017-01-01                 NaN                    NaN
# 4      2017-01-01             Central                    NaN
#
#   buildingclassdesc heatingorsystemdesc        propertylandusedesc storydesc  \
# 0               NaN                 NaN  Single Family Residential       NaN
# 1               NaN                 NaN  Single Family Residential       NaN
# 2               NaN                 NaN  Single Family Residential       NaN
# 3               NaN             Central  Single Family Residential       NaN
# 4               NaN             Central                Condominium       NaN
#
#   typeconstructiondesc
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %% [markdown]
# > What kind of data types are we working with? How many null values are in each column?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77580 entries, 0 to 77579
# Data columns (total 68 columns):
# id                              77580 non-null int64
# parcelid                        77580 non-null int64
# airconditioningtypeid           25007 non-null float64
# architecturalstyletypeid        207 non-null float64
# basementsqft                    50 non-null float64
# bathroomcnt                     77580 non-null float64
# bedroomcnt                      77580 non-null float64
# buildingclasstypeid             15 non-null float64
# buildingqualitytypeid           49810 non-null float64
# calculatedbathnbr               76964 non-null float64
# decktypeid                      614 non-null float64
# finishedfloor1squarefeet        6037 non-null float64
# calculatedfinishedsquarefeet    77379 non-null float64
# finishedsquarefeet12            73924 non-null float64
# finishedsquarefeet13            42 non-null float64
# finishedsquarefeet15            3027 non-null float64
# finishedsquarefeet50            6037 non-null float64
# finishedsquarefeet6             386 non-null float64
# fips                            77580 non-null float64
# fireplacecnt                    8289 non-null float64
# fullbathcnt                     76964 non-null float64
# garagecarcnt                    25520 non-null float64
# garagetotalsqft                 25520 non-null float64
# hashottuborspa                  1539 non-null float64
# heatingorsystemtypeid           49572 non-null float64
# latitude                        77580 non-null float64
# longitude                       77580 non-null float64
# lotsizesquarefeet               69322 non-null float64
# poolcnt                         16174 non-null float64
# poolsizesum                     869 non-null float64
# pooltypeid10                    465 non-null float64
# pooltypeid2                     1074 non-null float64
# pooltypeid7                     15079 non-null float64
# propertycountylandusecode       77580 non-null object
# propertylandusetypeid           77580 non-null float64
# propertyzoningdesc              50477 non-null object
# rawcensustractandblock          77580 non-null float64
# regionidcity                    76108 non-null float64
# regionidcounty                  77580 non-null float64
# regionidneighborhood            30974 non-null float64
# regionidzip                     77530 non-null float64
# roomcnt                         77580 non-null float64
# storytypeid                     50 non-null float64
# threequarterbathnbr             10106 non-null float64
# typeconstructiontypeid          223 non-null float64
# unitcnt                         50704 non-null float64
# yardbuildingsqft17              2393 non-null float64
# yardbuildingsqft26              70 non-null float64
# yearbuilt                       77310 non-null float64
# numberofstories                 17599 non-null float64
# fireplaceflag                   172 non-null float64
# structuretaxvaluedollarcnt      77465 non-null float64
# taxvaluedollarcnt               77579 non-null float64
# assessmentyear                  77580 non-null float64
# landtaxvaluedollarcnt           77578 non-null float64
# taxamount                       77575 non-null float64
# taxdelinquencyflag              2900 non-null object
# taxdelinquencyyear              2900 non-null float64
# censustractandblock             77333 non-null float64
# logerror                        77580 non-null float64
# transactiondate                 77580 non-null object
# airconditioningdesc             25007 non-null object
# architecturalstyledesc          207 non-null object
# buildingclassdesc               15 non-null object
# heatingorsystemdesc             49572 non-null object
# propertylandusedesc             77580 non-null object
# storydesc                       50 non-null object
# typeconstructiondesc            223 non-null object
# dtypes: float64(55), int64(2), object(11)
# memory usage: 40.8+ MB

# %% [markdown]
# > **We will need to address the abudance of null values and change some of the data types before we can begin our analysis.**

# %% [markdown]
# > Let's take a look at some of the summary statistics before we being preparing our data.

# %%
df.describe()
# Out:
#                  id      parcelid  airconditioningtypeid  \
# count  7.758000e+04  7.758000e+04           25007.000000
# mean   1.495404e+06  1.300828e+07               1.812013
# std    8.609700e+05  3.519376e+06               2.965768
# min    3.490000e+02  1.071186e+07               1.000000
# 25%    7.521430e+05  1.153820e+07               1.000000
# 50%    1.498256e+06  1.253056e+07               1.000000
# 75%    2.240950e+06  1.421135e+07               1.000000
# max    2.982274e+06  1.676893e+08              13.000000
#
#        architecturalstyletypeid  basementsqft   bathroomcnt    bedroomcnt  \
# count                207.000000     50.000000  77580.000000  77580.000000
# mean                   7.386473    679.720000      2.298492      3.053222
# std                    2.728030    689.703546      0.996726      1.140472
# min                    2.000000     38.000000      0.000000      0.000000
# 25%                    7.000000    273.000000      2.000000      2.000000
# 50%                    7.000000    515.000000      2.000000      3.000000
# 75%                    7.000000    796.500000      3.000000      4.000000
# max                   21.000000   3560.000000     18.000000     16.000000
#
#        buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  \
# count            15.000000           49810.000000       76964.000000
# mean              3.933333               6.533728           2.316388
# std               0.258199               1.722082           0.979684
# min               3.000000               1.000000           1.000000
# 25%               4.000000               6.000000           2.000000
# 50%               4.000000               6.000000           2.000000
# 75%               4.000000               8.000000           3.000000
# max               4.000000              12.000000          18.000000
#
#        decktypeid  finishedfloor1squarefeet  calculatedfinishedsquarefeet  \
# count       614.0               6037.000000                  77379.000000
# mean         66.0               1366.165314                   1784.925923
# std           0.0                670.701336                    954.247864
# min          66.0                 44.000000                    128.000000
# 25%          66.0                955.000000                   1182.000000
# 50%          66.0               1257.000000                   1542.000000
# 75%          66.0               1615.000000                   2112.000000
# max          66.0               6912.000000                  35640.000000
#
#        finishedsquarefeet12  finishedsquarefeet13  finishedsquarefeet15  \
# count          73924.000000             42.000000           3027.000000
# mean            1760.274945           1388.761905           2354.491245
# std              934.349898            122.220874           1186.985442
# min              128.000000           1056.000000            598.000000
# 25%             1172.000000           1344.000000           1624.000000
# 50%             1523.000000           1440.000000           2088.000000
# 75%             2075.000000           1440.000000           2831.000000
# max            21929.000000           1560.000000          35640.000000
#
#        finishedsquarefeet50  finishedsquarefeet6          fips  fireplacecnt  \
# count           6037.000000           386.000000  77580.000000   8289.000000
# mean            1381.388935          2082.500000   6048.813998      1.191217
# std              725.792665          1240.382784     20.747162      0.490980
# min               44.000000           380.000000   6037.000000      1.000000
# 25%              956.000000           993.750000   6037.000000      1.000000
# 50%             1259.000000          1812.500000   6037.000000      1.000000
# 75%             1621.000000          3053.500000   6059.000000      1.000000
# max            12467.000000          5598.000000   6111.000000      5.000000
#
#         fullbathcnt  garagecarcnt  garagetotalsqft  hashottuborspa  \
# count  76964.000000  25520.000000     25520.000000          1539.0
# mean       2.250104      1.815282       350.047061             1.0
# std        0.966486      0.588340       261.646070             0.0
# min        1.000000      0.000000         0.000000             1.0
# 25%        2.000000      2.000000         0.000000             1.0
# 50%        2.000000      2.000000       436.000000             1.0
# 75%        3.000000      2.000000       492.000000             1.0
# max       18.000000     14.000000      4251.000000             1.0
#
#        heatingorsystemtypeid      latitude     longitude  lotsizesquarefeet  \
# count           49572.000000  7.758000e+04  7.758000e+04       6.932200e+04
# mean                3.921811  3.400837e+07 -1.182037e+08       2.997309e+04
# std                 3.594770  2.652856e+05  3.594078e+05       1.233042e+05
# min                 1.000000  3.333953e+07 -1.194754e+08       2.360000e+02
# 25%                 2.000000  3.381463e+07 -1.184150e+08       5.700000e+03
# 50%                 2.000000  3.402200e+07 -1.181810e+08       7.206000e+03
# 75%                 7.000000  3.417431e+07 -1.179286e+08       1.183675e+04
# max                24.000000  3.481877e+07 -1.175546e+08       6.971010e+06
#
#        poolcnt  poolsizesum  pooltypeid10  pooltypeid2  pooltypeid7  \
# count  16174.0   869.000000         465.0       1074.0      15079.0
# mean       1.0   517.930955           1.0          1.0          1.0
# std        0.0   156.569664           0.0          0.0          0.0
# min        1.0    24.000000           1.0          1.0          1.0
# 25%        1.0   424.000000           1.0          1.0          1.0
# 50%        1.0   500.000000           1.0          1.0          1.0
# 75%        1.0   600.000000           1.0          1.0          1.0
# max        1.0  1500.000000           1.0          1.0          1.0
#
#        propertylandusetypeid  rawcensustractandblock   regionidcity  \
# count           77580.000000            7.758000e+04   76108.000000
# mean              261.824465            6.049124e+07   33684.165817
# std                 5.141564            2.058953e+05   47212.464556
# min                31.000000            6.037101e+07    3491.000000
# 25%               261.000000            6.037311e+07   12447.000000
# 50%               261.000000            6.037603e+07   25218.000000
# 75%               266.000000            6.059042e+07   45457.000000
# max               275.000000            6.111009e+07  396556.000000
#
#        regionidcounty  regionidneighborhood    regionidzip       roomcnt  \
# count    77580.000000          30974.000000   77530.000000  77580.000000
# mean      2534.522235         187725.110544   96586.691539      1.476257
# std        801.445328         165045.086058    3793.527616      2.823673
# min       1286.000000           6952.000000   95982.000000      0.000000
# 25%       1286.000000          46736.000000   96193.000000      0.000000
# 50%       3101.000000         118849.000000   96389.000000      0.000000
# 75%       3101.000000         274765.000000   96987.000000      0.000000
# max       3101.000000         764167.000000  399675.000000     15.000000
#
#        storytypeid  threequarterbathnbr  typeconstructiontypeid       unitcnt  \
# count         50.0         10106.000000              223.000000  50704.000000
# mean           7.0             1.009598                6.040359      1.110307
# std            0.0             0.118572                0.556035      1.169955
# min            7.0             1.000000                4.000000      1.000000
# 25%            7.0             1.000000                6.000000      1.000000
# 50%            7.0             1.000000                6.000000      1.000000
# 75%            7.0             1.000000                6.000000      1.000000
# max            7.0             7.000000               13.000000    237.000000
#
#        yardbuildingsqft17  yardbuildingsqft26     yearbuilt  numberofstories  \
# count         2393.000000           70.000000  77310.000000     17599.000000
# mean           305.460928          216.385714   1968.611396         1.434286
# std            238.735241          190.177514     23.793037         0.544515
# min             11.000000           12.000000   1824.000000         1.000000
# 25%            170.000000           61.500000   1953.000000         1.000000
# 50%            250.000000          164.500000   1970.000000         1.000000
# 75%            364.000000          310.500000   1987.000000         2.000000
# max           3191.000000          868.000000   2016.000000         6.000000
#
#        fireplaceflag  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# count          172.0                7.746500e+04       7.757900e+04
# mean             1.0                1.892796e+05       4.901476e+05
# std              0.0                2.304095e+05       6.537942e+05
# min              1.0                4.400000e+01       1.000000e+03
# 25%              1.0                8.417100e+04       2.068990e+05
# 50%              1.0                1.364020e+05       3.588780e+05
# 75%              1.0                2.187340e+05       5.690000e+05
# max              1.0                1.142179e+07       4.906124e+07
#
#        assessmentyear  landtaxvaluedollarcnt      taxamount  \
# count         77580.0           7.757800e+04   77575.000000
# mean           2016.0           3.011500e+05    5995.927626
# std               0.0           4.927219e+05    7628.816490
# min            2016.0           1.610000e+02      19.920000
# 25%            2016.0           8.529325e+04    2712.650000
# 50%            2016.0           2.031810e+05    4448.230000
# 75%            2016.0           3.667398e+05    6926.885000
# max            2016.0           4.895220e+07  586639.300000
#
#        taxdelinquencyyear  censustractandblock      logerror
# count         2900.000000         7.733300e+04  77580.000000
# mean            14.088276         6.049667e+13      0.016800
# std              2.181281         1.533329e+12      0.170739
# min              3.000000         6.037101e+13     -4.655420
# 25%             14.000000         6.037311e+13     -0.024310
# 50%             15.000000         6.037603e+13      0.006675
# 75%             15.000000         6.059042e+13      0.039291
# max             99.000000         4.830301e+14      5.262999

# %% [markdown]
# > Finally, let's plot the distributions of the data to help us identify outliers that need to be addressed.

# %%
# let's drop the numeric id fields as they will not serve us in our hunt for outliers.
df.drop(columns=["id", "parcelid", "airconditioningtypeid", "architecturalstyletypeid", "buildingclasstypeid", "buildingqualitytypeid", "decktypeid", "fips", "heatingorsystemtypeid", "pooltypeid10", "pooltypeid2", "pooltypeid7", "propertylandusetypeid", "rawcensustractandblock", "regionidcity", "regionidcounty", "regionidneighborhood", "regionidzip", "storytypeid", "typeconstructiontypeid", "fireplaceflag", "censustractandblock"]).hist(figsize=(32, 32))
plt.show()

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(x=df.calculatedfinishedsquarefeet)
plt.show()

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(x=df.lotsizesquarefeet)
plt.show()

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(x=df.taxamount)
plt.show()

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(x=df.structuretaxvaluedollarcnt)
plt.show()

# %% [markdown]
# > **Now that we have a general idea of what our data looks like and where outliers need to be addressed, let's move into preparation.**

# %% [markdown]
# ---
# # Prepare

# %% [markdown]
# ## Explanation of `prep_zillow` function
# The function does the following:
# 1. Removes any properties that cannot be interpreted as single unit/single family homes
# 2. Removes fields that will not add any value to our analysis (i.e., identifier fields and those with redundant information)
# 3. Drops columns and indices that are missing more than 60% of their respective data
# 4. Imputes missing values remaining after the function in number 3 has been called (excluding the `regionidcity` field)
# 5. Drops indices deemed unworthy of imputation either because there are too few values missing to put in the effort of imputing or imputation is not a practical means of handling the missing data (e.g., `censustractandblock`)
# 6. Creates new `county`, `tax_rate`, `yard_size`, and `price_per_sq_ft` variables
# 7. Detects and removes outliers
# 8. Resets the index of the DataFrame
# 9. Drops former index column

# %%
df = wr.prep_zillow(df)
print(df.shape)
df.head()
# Out:
# (44440, 33)
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  14297519          3.5         4.0                    6.0
# 1  17052889          1.0         2.0                    6.0
# 2  14186244          2.0         3.0                    6.0
# 3  12177905          3.0         4.0                    8.0
# 4  12069064          1.0         2.0                    5.0
#
#    calculatedbathnbr  calculatedfinishedsquarefeet    fips  fullbathcnt  \
# 0                3.5                        3100.0  6059.0          3.0
# 1                1.0                        1465.0  6111.0          1.0
# 2                2.0                        1243.0  6059.0          2.0
# 3                3.0                        2376.0  6037.0          3.0
# 4                1.0                         738.0  6037.0          1.0
#
#      latitude    longitude  lotsizesquarefeet propertycountylandusecode  \
# 0  33634931.0 -117869207.0             4506.0                       122
# 1  34449266.0 -119281531.0            12647.0                      1110
# 2  33886168.0 -117823170.0             8432.0                       122
# 3  34245180.0 -118240722.0            13038.0                      0101
# 4  34149214.0 -118239357.0             4214.0                      0100
#
#    rawcensustractandblock  regionidcity  regionidcounty  regionidzip  roomcnt  \
# 0            6.059063e+07       53571.0          1286.0      96978.0      0.0
# 1            6.111001e+07       13091.0          2061.0      97099.0      5.0
# 2            6.059022e+07       21412.0          1286.0      97078.0      6.0
# 3            6.037300e+07      396551.0          3101.0      96330.0      0.0
# 4            6.037302e+07       45457.0          3101.0      96325.0      0.0
#
#    unitcnt  yearbuilt  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 0      1.0     1998.0                    485713.0          1023282.0
# 1      1.0     1967.0                     88000.0           464000.0
# 2      1.0     1962.0                     85289.0           564778.0
# 3      1.0     1970.0                    108918.0           145143.0
# 4      1.0     1922.0                     18890.0           218552.0
#
#    assessmentyear  landtaxvaluedollarcnt  taxamount  censustractandblock  \
# 0          2016.0               537569.0   11013.72         6.059063e+13
# 1          2016.0               376000.0    5672.48         6.111001e+13
# 2          2016.0               479489.0    6488.30         6.059022e+13
# 3          2016.0                36225.0    1777.51         6.037300e+13
# 4          2016.0               199662.0    2366.08         6.037302e+13
#
#    logerror transactiondate heatingorsystemdesc        propertylandusedesc  \
# 0  0.025595      2017-01-01                None  Single Family Residential
# 1  0.055619      2017-01-01                None  Single Family Residential
# 2  0.005383      2017-01-01                None  Single Family Residential
# 3 -0.103410      2017-01-01             Central  Single Family Residential
# 4  0.101723      2017-01-01                None  Single Family Residential
#
#                county  tax_rate  yard_size  price_per_sq_ft
# 0       Orange County  0.010763     1406.0       330.090968
# 1      Ventura County  0.012225    11182.0       316.723549
# 2       Orange County  0.011488     7189.0       454.366854
# 3  Los Angeles County  0.012247    10662.0        61.087121
# 4  Los Angeles County  0.010826     3476.0       296.140921

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(x=df.calculatedfinishedsquarefeet)
plt.show()

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(x=df.lotsizesquarefeet)
plt.show()

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(x=df.taxamount)
plt.show()

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(x=df.structuretaxvaluedollarcnt)
plt.show()

# %% [markdown]
# > Looks like the outliers have been handled.

# %% [markdown]
# ## Preprocessing
#
# ### Explanation of `split_impute_scale` function
# The function does the following:
# 1. Splits prepared DataFrame into `train`, `validate`, and `test`
# 2. KNN imputes the regionidcity for `train`, `validate`, and `test`
# 3. Scales all appropriate numeric fields for `train`, `validate`, and `test`
# 4. Returns the `imputer`, `scaler`, `train`, `validate`, and `test` variables

# %%
imputer, scaler, train, validate, test = pr.split_impute_scale(df)
imputer
# Out:
# KNNImputer(add_indicator=False, copy=True, metric='nan_euclidean',
#            missing_values=nan, n_neighbors=5, weights='uniform')

# %%
scaler
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
print(f"   train shape = {train.shape}")
print(f"validate shape = {validate.shape}")
print(f"    test shape = {test.shape}")
# Out:
#    train shape = (26664, 33)
# validate shape = (8888, 33)
#     test shape = (8888, 33)

# %%
train.head()
# Out:
#        parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 35915  12457622          0.0    0.333333                    0.2
# 40456  12906513          0.2    0.333333                    0.5
# 13143  14023137          0.2    0.333333                    0.5
# 5357   11459439          0.2    0.500000                    0.3
# 21808  11461483          0.0    0.333333                    0.5
#
#        calculatedbathnbr  calculatedfinishedsquarefeet  fips  fullbathcnt  \
# 35915                0.0                      0.196721  6037          0.0
# 40456                0.2                      0.191389  6037          0.2
# 13143                0.2                      0.223385  6059          0.2
# 5357                 0.2                      0.256962  6037          0.2
# 21808                0.0                      0.194549  6037          0.0
#
#        latitude  longitude  lotsizesquarefeet propertycountylandusecode  \
# 35915  0.372619   0.663738           0.390181                      0100
# 40456  0.557788   0.876809           0.415971                      0100
# 13143  0.268013   0.825818           0.311512                       122
# 5357   0.456542   0.550515           0.298815                      0100
# 21808  0.452833   0.547211           0.243679                      0100
#
#        rawcensustractandblock regionidcity regionidcounty regionidzip  \
# 35915                0.006367        46298           3101       96239
# 40456                0.004048        39308           3101       96494
# 13143                0.297302        47568           1286       97004
# 5357                 0.002372        12447           3101       96026
# 21808                0.002373        12447           3101       96026
#
#         roomcnt  unitcnt  yearbuilt  structuretaxvaluedollarcnt  \
# 35915  0.000000      0.0   0.328467                    0.100685
# 40456  0.000000      0.0   0.620438                    0.154533
# 13143  0.583333      0.0   0.642336                    0.071548
# 5357   0.000000      0.0   0.510949                    0.210432
# 21808  0.000000      0.0   0.510949                    0.298840
#
#        taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 35915           0.123589             0.0               0.122217   0.139519
# 40456           0.074533             0.0               0.031406   0.086354
# 13143           0.037447             0.0               0.022059   0.051657
# 5357            0.398417             0.0               0.433715   0.425683
# 21808           0.406335             0.0               0.401818   0.431475
#
#        censustractandblock  logerror transactiondate heatingorsystemdesc  \
# 35915             0.006367  0.639213      2017-07-31          Floor/Wall
# 40456             0.004048  0.638314      2017-08-25             Central
# 13143             0.297302  0.633058      2017-04-04                None
# 5357              0.002372  0.632350      2017-02-13          Floor/Wall
# 21808             0.002373  0.638097      2017-05-22          Floor/Wall
#
#              propertylandusedesc              county  tax_rate  yard_size  \
# 35915  Single Family Residential  Los Angeles County  0.494151   0.444233
# 40456  Single Family Residential  Los Angeles County  0.500428   0.473054
# 13143  Single Family Residential       Orange County  0.614679   0.353183
# 5357   Single Family Residential  Los Angeles County  0.463512   0.329661
# 21808  Single Family Residential  Los Angeles County  0.458386   0.290300
#
#        price_per_sq_ft
# 35915         0.182773
# 40456         0.111496
# 13143         0.046645
# 5357          0.480345
# 21808         0.614044

# %%
train.isna().sum()
# Out:
# parcelid                        0
# bathroomcnt                     0
# bedroomcnt                      0
# buildingqualitytypeid           0
# calculatedbathnbr               0
# calculatedfinishedsquarefeet    0
# fips                            0
# fullbathcnt                     0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# propertycountylandusecode       0
# rawcensustractandblock          0
# regionidcity                    0
# regionidcounty                  0
# regionidzip                     0
# roomcnt                         0
# unitcnt                         0
# yearbuilt                       0
# structuretaxvaluedollarcnt      0
# taxvaluedollarcnt               0
# assessmentyear                  0
# landtaxvaluedollarcnt           0
# taxamount                       0
# censustractandblock             0
# logerror                        0
# transactiondate                 0
# heatingorsystemdesc             0
# propertylandusedesc             0
# county                          0
# tax_rate                        0
# yard_size                       0
# price_per_sq_ft                 0
# dtype: int64

# %%
validate.isna().sum()
# Out:
# parcelid                        0
# bathroomcnt                     0
# bedroomcnt                      0
# buildingqualitytypeid           0
# calculatedbathnbr               0
# calculatedfinishedsquarefeet    0
# fips                            0
# fullbathcnt                     0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# propertycountylandusecode       0
# rawcensustractandblock          0
# regionidcity                    0
# regionidcounty                  0
# regionidzip                     0
# roomcnt                         0
# unitcnt                         0
# yearbuilt                       0
# structuretaxvaluedollarcnt      0
# taxvaluedollarcnt               0
# assessmentyear                  0
# landtaxvaluedollarcnt           0
# taxamount                       0
# censustractandblock             0
# logerror                        0
# transactiondate                 0
# heatingorsystemdesc             0
# propertylandusedesc             0
# county                          0
# tax_rate                        0
# yard_size                       0
# price_per_sq_ft                 0
# dtype: int64

# %%
test.isna().sum()
# Out:
# parcelid                        0
# bathroomcnt                     0
# bedroomcnt                      0
# buildingqualitytypeid           0
# calculatedbathnbr               0
# calculatedfinishedsquarefeet    0
# fips                            0
# fullbathcnt                     0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# propertycountylandusecode       0
# rawcensustractandblock          0
# regionidcity                    0
# regionidcounty                  0
# regionidzip                     0
# roomcnt                         0
# unitcnt                         0
# yearbuilt                       0
# structuretaxvaluedollarcnt      0
# taxvaluedollarcnt               0
# assessmentyear                  0
# landtaxvaluedollarcnt           0
# taxamount                       0
# censustractandblock             0
# logerror                        0
# transactiondate                 0
# heatingorsystemdesc             0
# propertylandusedesc             0
# county                          0
# tax_rate                        0
# yard_size                       0
# price_per_sq_ft                 0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26664 entries, 35915 to 44208
# Data columns (total 33 columns):
# parcelid                        26664 non-null object
# bathroomcnt                     26664 non-null float64
# bedroomcnt                      26664 non-null float64
# buildingqualitytypeid           26664 non-null float64
# calculatedbathnbr               26664 non-null float64
# calculatedfinishedsquarefeet    26664 non-null float64
# fips                            26664 non-null object
# fullbathcnt                     26664 non-null float64
# latitude                        26664 non-null float64
# longitude                       26664 non-null float64
# lotsizesquarefeet               26664 non-null float64
# propertycountylandusecode       26664 non-null object
# rawcensustractandblock          26664 non-null float64
# regionidcity                    26664 non-null object
# regionidcounty                  26664 non-null object
# regionidzip                     26664 non-null object
# roomcnt                         26664 non-null float64
# unitcnt                         26664 non-null float64
# yearbuilt                       26664 non-null float64
# structuretaxvaluedollarcnt      26664 non-null float64
# taxvaluedollarcnt               26664 non-null float64
# assessmentyear                  26664 non-null float64
# landtaxvaluedollarcnt           26664 non-null float64
# taxamount                       26664 non-null float64
# censustractandblock             26664 non-null float64
# logerror                        26664 non-null float64
# transactiondate                 26664 non-null object
# heatingorsystemdesc             26664 non-null object
# propertylandusedesc             26664 non-null object
# county                          26664 non-null object
# tax_rate                        26664 non-null float64
# yard_size                       26664 non-null float64
# price_per_sq_ft                 26664 non-null float64
# dtypes: float64(23), object(10)
# memory usage: 6.9+ MB

# %%
train.describe()
# Out:
#         bathroomcnt    bedroomcnt  buildingqualitytypeid  calculatedbathnbr  \
# count  26664.000000  26664.000000           26664.000000       26664.000000
# mean       0.235599      0.375281               0.506353           0.235610
# std        0.164639      0.145734               0.125317           0.164631
# min        0.000000      0.000000               0.000000           0.000000
# 25%        0.200000      0.333333               0.500000           0.200000
# 50%        0.200000      0.333333               0.500000           0.200000
# 75%        0.400000      0.500000               0.500000           0.400000
# max        1.000000      1.000000               1.000000           1.000000
#
#        calculatedfinishedsquarefeet   fullbathcnt      latitude     longitude  \
# count                  26664.000000  26664.000000  26664.000000  26664.000000
# mean                       0.290394      0.223192      0.483721      0.667710
# std                        0.140015      0.161033      0.191289      0.188599
# min                        0.000000      0.000000      0.000000      0.000000
# 25%                        0.188623      0.200000      0.347763      0.559738
# 50%                        0.257555      0.200000      0.476627      0.691754
# 75%                        0.362631      0.400000      0.608299      0.806844
# max                        1.000000      1.000000      1.000000      1.000000
#
#        lotsizesquarefeet  rawcensustractandblock       roomcnt  unitcnt  \
# count       26664.000000            26664.000000  26664.000000  26664.0
# mean            0.369073                0.171338      0.166867      0.0
# std             0.155072                0.281994      0.263833      0.0
# min             0.000000                0.000000      0.000000      0.0
# 25%             0.281321                0.004059      0.000000      0.0
# 50%             0.345598                0.006766      0.000000      0.0
# 75%             0.425790                0.297008      0.416667      0.0
# max             1.000000                1.000000      1.000000      0.0
#
#           yearbuilt  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# count  26664.000000                26664.000000       26664.000000
# mean       0.614816                    0.232658           0.219352
# std        0.162610                    0.169416           0.161463
# min        0.000000                    0.000000           0.000000
# 25%        0.525547                    0.113620           0.099747
# 50%        0.598540                    0.186139           0.189161
# 75%        0.722628                    0.301223           0.295778
# max        1.000000                    1.000000           1.000000
#
#        assessmentyear  landtaxvaluedollarcnt     taxamount  \
# count         26664.0           26664.000000  26664.000000
# mean              0.0               0.185819      0.235188
# std               0.0               0.162575      0.161092
# min               0.0               0.000000      0.000000
# 25%               0.0               0.057253      0.121221
# 50%               0.0               0.149651      0.204950
# 75%               0.0               0.266565      0.307096
# max               0.0               1.000000      1.000000
#
#        censustractandblock      logerror      tax_rate     yard_size  \
# count         26664.000000  26664.000000  26664.000000  26664.000000
# mean              0.171363      0.639572      0.506974      0.393719
# std               0.281993      0.023093      0.141135      0.152825
# min               0.000000      0.000000      0.000000      0.000000
# 25%               0.004060      0.633759      0.423053      0.309653
# 50%               0.006769      0.638018      0.469987      0.377479
# 75%               0.297008      0.642504      0.554137      0.455428
# max               1.000000      1.000000      1.000000      1.000000
#
#        price_per_sq_ft
# count     26664.000000
# mean          0.240556
# std           0.158046
# min           0.000000
# 25%           0.122566
# 50%           0.223358
# 75%           0.326916
# max           1.000000

# %%
train = wr.convert_dtypes(train, columns=["parcelid", "buildingqualitytypeid", "unitcnt", "assessmentyear", "rawcensustractandblock", "censustractandblock"], dtype="object")
train.hist(figsize=(16, 16))
plt.show()

# %% [markdown]
# # Explore

# %%
# sns.pairplot(data=train.drop(columns=["parcelid", "buildingqualitytypeid", "unitcnt", "assessmentyear", "rawcensustractandblock", "censustractandblock"]))

# %%
plt.figure(figsize=(16, 16))
sns.heatmap(train.corr(), annot=True, cmap="Blues")
plt.show()

# %% [markdown]
# ## Cluster the Target Variable
# Objectives:
# 1. Reduce the noise of the continuous variable so that trends in the data are more easily identifiable
# 2. Compare clusters with other variables through visualizations or hypothesis testing

# %%
X = train[["logerror"]]

# %%
# inital intuition of 6 clusters
kmeans = KMeans(n_clusters=6)
kmeans.fit(X)
kmeans.predict(X)
# Out:
# array([0, 0, 0, ..., 0, 0, 2], dtype=int32)

# %%
plt.figure(figsize=(10, 10))
pd.Series({k: ex.get_inertia(k, X) for k in range(2, 21)}).plot()
plt.grid()
plt.xlabel("k")
plt.ylabel("inertia")
plt.xticks(range(1, 21))
plt.show()

# %% [markdown]
# > **6 or 7 seem like reasonable values for k**

# %%
# according to the elbow method above 7 clusters also seems reasonable
kmeans = KMeans(n_clusters=7)
kmeans.fit(X)
train["cluster_target"] = kmeans.predict(X)
train.head()
# Out:
#        parcelid  bathroomcnt  bedroomcnt buildingqualitytypeid  \
# 35915  12457622          0.0    0.333333                   0.2
# 40456  12906513          0.2    0.333333                   0.5
# 13143  14023137          0.2    0.333333                   0.5
# 5357   11459439          0.2    0.500000                   0.3
# 21808  11461483          0.0    0.333333                   0.5
#
#        calculatedbathnbr  calculatedfinishedsquarefeet  fips  fullbathcnt  \
# 35915                0.0                      0.196721  6037          0.0
# 40456                0.2                      0.191389  6037          0.2
# 13143                0.2                      0.223385  6059          0.2
# 5357                 0.2                      0.256962  6037          0.2
# 21808                0.0                      0.194549  6037          0.0
#
#        latitude  longitude  lotsizesquarefeet propertycountylandusecode  \
# 35915  0.372619   0.663738           0.390181                      0100
# 40456  0.557788   0.876809           0.415971                      0100
# 13143  0.268013   0.825818           0.311512                       122
# 5357   0.456542   0.550515           0.298815                      0100
# 21808  0.452833   0.547211           0.243679                      0100
#
#       rawcensustractandblock regionidcity regionidcounty regionidzip  \
# 35915             0.00636725        46298           3101       96239
# 40456             0.00404817        39308           3101       96494
# 13143               0.297302        47568           1286       97004
# 5357              0.00237173        12447           3101       96026
# 21808             0.00237309        12447           3101       96026
#
#         roomcnt unitcnt  yearbuilt  structuretaxvaluedollarcnt  \
# 35915  0.000000       0   0.328467                    0.100685
# 40456  0.000000       0   0.620438                    0.154533
# 13143  0.583333       0   0.642336                    0.071548
# 5357   0.000000       0   0.510949                    0.210432
# 21808  0.000000       0   0.510949                    0.298840
#
#        taxvaluedollarcnt assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 35915           0.123589              0               0.122217   0.139519
# 40456           0.074533              0               0.031406   0.086354
# 13143           0.037447              0               0.022059   0.051657
# 5357            0.398417              0               0.433715   0.425683
# 21808           0.406335              0               0.401818   0.431475
#
#       censustractandblock  logerror transactiondate heatingorsystemdesc  \
# 35915          0.00636725  0.639213      2017-07-31          Floor/Wall
# 40456          0.00404817  0.638314      2017-08-25             Central
# 13143            0.297302  0.633058      2017-04-04                None
# 5357           0.00237173  0.632350      2017-02-13          Floor/Wall
# 21808          0.00237309  0.638097      2017-05-22          Floor/Wall
#
#              propertylandusedesc              county  tax_rate  yard_size  \
# 35915  Single Family Residential  Los Angeles County  0.494151   0.444233
# 40456  Single Family Residential  Los Angeles County  0.500428   0.473054
# 13143  Single Family Residential       Orange County  0.614679   0.353183
# 5357   Single Family Residential  Los Angeles County  0.463512   0.329661
# 21808  Single Family Residential  Los Angeles County  0.458386   0.290300
#
#        price_per_sq_ft  cluster_target
# 35915         0.182773               3
# 40456         0.111496               3
# 13143         0.046645               0
# 5357          0.480345               0
# 21808         0.614044               3

# %%
centriods = pd.DataFrame(kmeans.cluster_centers_, columns=X.columns)
centriods
# Out:
#    logerror
# 0  0.626552
# 1  0.667026
# 2  0.935394
# 3  0.639864
# 4  0.313495
# 5  0.575604
# 6  0.733685

# %%
train.groupby("cluster_target")["logerror"].mean()
# Out:
# cluster_target
# 0    0.626578
# 1    0.666979
# 2    0.935394
# 3    0.639865
# 4    0.313495
# 5    0.575850
# 6    0.733566
# Name: logerror, dtype: float64

# %% [markdown]
# > **There are two centroids for lower (0.29) and upper (0.85) outlier clusters. Generally, the centriods fall in between 0.51 and 0.65 indicating that most of the clusters are grouped close together**

# %%
train.cluster_target.hist()

# %%
train.logerror.hist()

# %%
plt.figure(figsize=(10, 10))

for cluster, subset in train.groupby("cluster_target"):
    plt.scatter(subset.longitude, subset.latitude, label="cluster" + str(cluster), alpha=.6)

plt.legend()

# %% [markdown]
# > **This visualization leads me to believe that the mean logerror by county is the same.**

# %% [markdown]
# $H_0$: The mean logerror by county is the same
#
# $H_0$: The mean logerror by county is different

# %%
alpha = .001

la = train[train.county == "Los Angeles County"].logerror
orange = train[train.county == "Orange County"].logerror
ventura = train[train.county == "Ventura County"].logerror

f, p = stats.f_oneway(la, orange, ventura)
print(f"statistic = {f}")
print(f"  p-value = {p}")
print()
if p < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# statistic = 12.547312509598612
#   p-value = 3.5754799354519303e-06
#
# Reject null hypothesis

# %%
plt.figure(figsize=(10, 10))

for cluster, subset in train.groupby("cluster_target"):
    plt.scatter(subset.calculatedfinishedsquarefeet, subset.lotsizesquarefeet, label="cluster" + str(cluster), alpha=.6)

plt.legend()

# %% [markdown]
# ## Cluster Independent Variables
# ### Cluster by Location

# %%
X = train[["latitude", "longitude"]]

# %%
plt.figure(figsize=(10, 10))
pd.Series({k: ex.get_inertia(k, X) for k in range(2, 21)}).plot()
plt.grid()
plt.xlabel("k")
plt.ylabel("inertia")
plt.xticks(range(1, 21))
plt.show()

# %%
kmeans = KMeans(n_clusters=7)
kmeans.fit(X)
train["location_cluster"] = kmeans.predict(X)

# %%
centriods = pd.DataFrame(kmeans.cluster_centers_, columns=X.columns)
centriods
# Out:
#    latitude  longitude
# 0  0.426174   0.610333
# 1  0.943388   0.688179
# 2  0.181943   0.924920
# 3  0.341732   0.790350
# 4  0.653769   0.227970
# 5  0.649789   0.511189
# 6  0.536503   0.770351

# %%
train.groupby("location_cluster")["latitude", "longitude"].mean()
# Out:
#                   latitude  longitude
# location_cluster
# 0                 0.426432   0.610122
# 1                 0.943388   0.688179
# 2                 0.181943   0.924920
# 3                 0.341917   0.790186
# 4                 0.653739   0.227826
# 5                 0.649920   0.511042
# 6                 0.536630   0.770428

# %%
plt.figure(figsize=(10, 10))

for cluster, subset in train.groupby("location_cluster"):
    plt.scatter(subset.longitude, subset.latitude, label="cluster" + str(cluster), alpha=.6)

centriods.plot.scatter(x="longitude", y="latitude", c="black", marker="x", s=1000, ax=plt.gca(), label="centriod")    

plt.legend()
plt.title("Southern California Clustered by Location")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# > Here we are able to see our properties clustered by geographic location.

# %% [markdown]
# ---
# ### Cluster by Size

# %%
X = train[["calculatedfinishedsquarefeet", "lotsizesquarefeet"]]

# %%
plt.figure(figsize=(10, 10))
pd.Series({k: ex.get_inertia(k, X) for k in range(2, 21)}).plot()
plt.grid()
plt.xlabel("k")
plt.ylabel("inertia")
plt.xticks(range(1, 21))
plt.show()

# %%
kmeans = KMeans(n_clusters=7)
kmeans.fit(X)
train["size_cluster"] = kmeans.predict(X)

# %%
centriods = pd.DataFrame(kmeans.cluster_centers_, columns=X.columns)
centriods
# Out:
#    calculatedfinishedsquarefeet  lotsizesquarefeet
# 0                      0.244397           0.408111
# 1                      0.594533           0.435741
# 2                      0.181611           0.301765
# 3                      0.328590           0.589731
# 4                      0.210669           0.129611
# 5                      0.393784           0.311084
# 6                      0.510889           0.818280

# %%
train.groupby("size_cluster")["calculatedfinishedsquarefeet", "lotsizesquarefeet"].mean()
# Out:
#               calculatedfinishedsquarefeet  lotsizesquarefeet
# size_cluster
# 0                                 0.244634           0.407891
# 1                                 0.594700           0.435830
# 2                                 0.181571           0.301764
# 3                                 0.328635           0.589517
# 4                                 0.210704           0.129652
# 5                                 0.394120           0.310946
# 6                                 0.510606           0.818506

# %%
plt.figure(figsize=(10, 10))

for cluster, subset in train.groupby("size_cluster"):
    plt.scatter(subset.calculatedfinishedsquarefeet, subset.lotsizesquarefeet, label="cluster" + str(cluster), alpha=.6)

centriods.plot.scatter(x="calculatedfinishedsquarefeet", y="lotsizesquarefeet", c="black", marker="x", s=1000, ax=plt.gca(), label="centriod")    
    
plt.legend()
plt.title("Clusters by Size of Property")
plt.xlabel("Total Finished Living Area (percentile)")
plt.ylabel("Area of Lot (percentile)")
plt.show()

# %% [markdown]
# > Here we are able to see our properties clustered by size.

# %% [markdown]
# ---
# ### Cluster by Location & Size

# %%
X = train[["latitude", "longitude", "calculatedfinishedsquarefeet", "lotsizesquarefeet"]]

# %%
plt.figure(figsize=(10, 10))
pd.Series({k: ex.get_inertia(k, X) for k in range(2, 21)}).plot()
plt.grid()
plt.xlabel("k")
plt.ylabel("inertia")
plt.xticks(range(1, 21))
plt.show()

# %%
kmeans = KMeans(n_clusters=9)
kmeans.fit(X)
train["location_size_cluster"] = kmeans.predict(X)
train.head()
# Out:
#        parcelid  bathroomcnt  bedroomcnt buildingqualitytypeid  \
# 35915  12457622          0.0    0.333333                   0.2
# 40456  12906513          0.2    0.333333                   0.5
# 13143  14023137          0.2    0.333333                   0.5
# 5357   11459439          0.2    0.500000                   0.3
# 21808  11461483          0.0    0.333333                   0.5
#
#        calculatedbathnbr  calculatedfinishedsquarefeet  fips  fullbathcnt  \
# 35915                0.0                      0.196721  6037          0.0
# 40456                0.2                      0.191389  6037          0.2
# 13143                0.2                      0.223385  6059          0.2
# 5357                 0.2                      0.256962  6037          0.2
# 21808                0.0                      0.194549  6037          0.0
#
#        latitude  longitude  lotsizesquarefeet propertycountylandusecode  \
# 35915  0.372619   0.663738           0.390181                      0100
# 40456  0.557788   0.876809           0.415971                      0100
# 13143  0.268013   0.825818           0.311512                       122
# 5357   0.456542   0.550515           0.298815                      0100
# 21808  0.452833   0.547211           0.243679                      0100
#
#       rawcensustractandblock regionidcity regionidcounty regionidzip  \
# 35915             0.00636725        46298           3101       96239
# 40456             0.00404817        39308           3101       96494
# 13143               0.297302        47568           1286       97004
# 5357              0.00237173        12447           3101       96026
# 21808             0.00237309        12447           3101       96026
#
#         roomcnt unitcnt  yearbuilt  structuretaxvaluedollarcnt  \
# 35915  0.000000       0   0.328467                    0.100685
# 40456  0.000000       0   0.620438                    0.154533
# 13143  0.583333       0   0.642336                    0.071548
# 5357   0.000000       0   0.510949                    0.210432
# 21808  0.000000       0   0.510949                    0.298840
#
#        taxvaluedollarcnt assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 35915           0.123589              0               0.122217   0.139519
# 40456           0.074533              0               0.031406   0.086354
# 13143           0.037447              0               0.022059   0.051657
# 5357            0.398417              0               0.433715   0.425683
# 21808           0.406335              0               0.401818   0.431475
#
#       censustractandblock  logerror transactiondate heatingorsystemdesc  \
# 35915          0.00636725  0.639213      2017-07-31          Floor/Wall
# 40456          0.00404817  0.638314      2017-08-25             Central
# 13143            0.297302  0.633058      2017-04-04                None
# 5357           0.00237173  0.632350      2017-02-13          Floor/Wall
# 21808          0.00237309  0.638097      2017-05-22          Floor/Wall
#
#              propertylandusedesc              county  tax_rate  yard_size  \
# 35915  Single Family Residential  Los Angeles County  0.494151   0.444233
# 40456  Single Family Residential  Los Angeles County  0.500428   0.473054
# 13143  Single Family Residential       Orange County  0.614679   0.353183
# 5357   Single Family Residential  Los Angeles County  0.463512   0.329661
# 21808  Single Family Residential  Los Angeles County  0.458386   0.290300
#
#        price_per_sq_ft  cluster_target  location_cluster  size_cluster  \
# 35915         0.182773               3                 0             0
# 40456         0.111496               3                 6             0
# 13143         0.046645               0                 3             2
# 5357          0.480345               0                 0             2
# 21808         0.614044               3                 0             2
#
#        location_size_cluster
# 35915                      6
# 40456                      1
# 13143                      4
# 5357                       6
# 21808                      6

# %%
centriods = pd.DataFrame(kmeans.cluster_centers_, columns=X.columns)
centriods
# Out:
#    latitude  longitude  calculatedfinishedsquarefeet  lotsizesquarefeet
# 0  0.631026   0.533031                      0.261726           0.372181
# 1  0.448740   0.791176                      0.237907           0.387135
# 2  0.436681   0.792218                      0.408537           0.674727
# 3  0.636222   0.467985                      0.497246           0.638111
# 4  0.248296   0.861946                      0.256887           0.209409
# 5  0.941677   0.686992                      0.313751           0.411780
# 6  0.424657   0.641085                      0.195932           0.272393
# 7  0.658386   0.217811                      0.292969           0.353749
# 8  0.245529   0.869739                      0.499658           0.368606

# %%
plt.figure(figsize=(10, 10))

for cluster, subset in train.groupby("location_size_cluster"):
    plt.scatter(subset.longitude, subset.latitude, label="cluster" + str(cluster), alpha=.6)

centriods.plot.scatter(x="longitude", y="latitude", c="black", marker="x", s=1000, ax=plt.gca(), label="centriod")    
    
plt.legend()
plt.title("Southern California Clustered by Location & Size")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# > This visulization is not very useful, but we'll keep it to document some exploration.

# %% [markdown]
# # Model

# %%
pd.options.display.float_format = '{:.3f}'.format

# %% [markdown]
# > Let's subset our data to experiment with different models

# %%
size_cluster0 = train[train.size_cluster == 0]
size_cluster1 = train[train.size_cluster == 1]
size_cluster2 = train[train.size_cluster == 2]
size_cluster3 = train[train.size_cluster == 3]
size_cluster4 = train[train.size_cluster == 4]
size_cluster5 = train[train.size_cluster == 5]
size_cluster6 = train[train.size_cluster == 6]

# %% [markdown]
# ---
# ### size_cluster0 Model 1 logerror ~ price_per_sq_ft + buildingqualitytypeid + tax_rate

# %%
cluster0_predictions = pd.DataFrame({
    "actual_logerror": size_cluster0.logerror,
    "baseline_logerror": size_cluster0.logerror.mean()
})

cluster0_predictions.head()
# Out:
#        actual_logerror  baseline_logerror
# 35915            0.639              0.639
# 40456            0.638              0.639
# 17922            0.636              0.639
# 29642            0.684              0.639
# 30307            0.641              0.639

# %%
X = size_cluster0[["price_per_sq_ft", "buildingqualitytypeid", "tax_rate"]]
# target
y = size_cluster0.logerror

# 1. Make the model
lm = sklearn.linear_model.LinearRegression()
# 2. Fit the model
lm.fit(X, y)
# 3. Use the model
cluster0_predictions["logerror ~ price_per_sq_ft + buildingqualitytypeid + tax_rate"] = lm.predict(X)
cluster0_predictions.head()
# Out:
#        actual_logerror  baseline_logerror  \
# 35915            0.639              0.639
# 40456            0.638              0.639
# 17922            0.636              0.639
# 29642            0.684              0.639
# 30307            0.641              0.639
#
#        logerror ~ price_per_sq_ft + buildingqualitytypeid + tax_rate
# 35915                                              0.641
# 40456                                              0.640
# 17922                                              0.639
# 29642                                              0.640
# 30307                                              0.639

# %%
plt.figure(figsize=(16, 8))
ev.plot_residuals(cluster0_predictions.actual_logerror, cluster0_predictions["logerror ~ price_per_sq_ft + buildingqualitytypeid + tax_rate"])
plt.ticklabel_format(axis="both", style="plain")
plt.show()

# %%
print(f"""The equation of our regression line is: 
y = ({lm.coef_[0]:.2f} * price_per_sq_ft) + ({lm.coef_[1]:.2f} * buildingqualitytypeid) + ({lm.coef_[-1]:.2f} * tax_rate) + {lm.intercept_:.2f}""")
# Out:
# The equation of our regression line is:
# y = (-0.01 * price_per_sq_ft) + (-0.01 * buildingqualitytypeid) + (-0.00 * tax_rate) + 0.64

# %%
ev.regression_errors(cluster0_predictions.actual_logerror, cluster0_predictions["logerror ~ price_per_sq_ft + buildingqualitytypeid + tax_rate"], cluster0_predictions)
# Out:
# SSE    2.622
# ESS    0.010
# TSS    2.632
# MSE    0.000
# RMSE   0.021
# dtype: float64

# %%
cluster0_predictions.apply(lambda c: math.sqrt(sklearn.metrics.mean_squared_error(cluster0_predictions.actual_logerror, c)))
# Out:
# actual_logerror                                                 0.000
# baseline_logerror                                               0.021
# logerror ~ price_per_sq_ft + buildingqualitytypeid + tax_rate   0.021
# dtype: float64

# %% [markdown]
# > Our baseline RMSE and model RMSE for logerror are the same.

# %%
ev.better_than_baseline(cluster0_predictions.actual_logerror, cluster0_predictions["logerror ~ price_per_sq_ft + buildingqualitytypeid + tax_rate"], cluster0_predictions.baseline_logerror, cluster0_predictions)
# Out:
# Model performs better than baseline

# %% [markdown]
# > According to our better_than_baseline function, our model is performing better than the baseline.

# %%
plt.figure(figsize=(16, 8))
sns.regplot(x=cluster0_predictions.actual_logerror, y=cluster0_predictions["logerror ~ price_per_sq_ft + buildingqualitytypeid + tax_rate"], data=cluster0_predictions, label="logerror ~ price_per_sq_ft + buildingqualitytypeid + tax_rate", line_kws={"color": sns.color_palette("colorblind")[4]})
plt.ticklabel_format(axis="both", style="plain")

plt.title("Actual v. Predicted Logerror")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.legend()

plt.show()

# %% [markdown]
# ---
# ### size_cluster0 Model 2 logerror ~ calculatedfinishedsquarefeet + lotsizesquarefeet¶

# %%
X = size_cluster0[["calculatedfinishedsquarefeet", "lotsizesquarefeet"]]
# target
y = size_cluster0.logerror

# 1. Make the model
lm = sklearn.linear_model.LinearRegression()
# 2. Fit the model
lm.fit(X, y)
# 3. Use the model
cluster0_predictions["logerror ~ calculatedfinishedsquarefeet + lotsizesquarefeet"] = lm.predict(X)
cluster0_predictions.head()
# Out:
#        actual_logerror  baseline_logerror  \
# 35915            0.639              0.639
# 40456            0.638              0.639
# 17922            0.636              0.639
# 29642            0.684              0.639
# 30307            0.641              0.639
#
#        logerror ~ price_per_sq_ft + buildingqualitytypeid + tax_rate  \
# 35915                                              0.641
# 40456                                              0.640
# 17922                                              0.639
# 29642                                              0.640
# 30307                                              0.639
#
#        logerror ~ calculatedfinishedsquarefeet + lotsizesquarefeet
# 35915                                              0.639
# 40456                                              0.639
# 17922                                              0.639
# 29642                                              0.639
# 30307                                              0.640

# %%
plt.figure(figsize=(16, 8))
ev.plot_residuals(cluster0_predictions.actual_logerror, cluster0_predictions["logerror ~ calculatedfinishedsquarefeet + lotsizesquarefeet"])
plt.ticklabel_format(axis="both", style="plain")
plt.show()

# %%
print(f"""The equation of our regression line is: 
y = ({lm.coef_[0]:.2f} * calculatedfinishedsquarefeet) + ({lm.coef_[1]:.2f} * lotsizesquarefeet) + {lm.intercept_:.2f}""")
# Out:
# The equation of our regression line is:
# y = (0.00 * calculatedfinishedsquarefeet) + (0.01 * lotsizesquarefeet) + 0.64

# %%
ev.regression_errors(cluster0_predictions.actual_logerror, cluster0_predictions["logerror ~ calculatedfinishedsquarefeet + lotsizesquarefeet"], cluster0_predictions)
# Out:
# SSE    2.631
# ESS    0.001
# TSS    2.632
# MSE    0.000
# RMSE   0.021
# dtype: float64

# %%
cluster0_predictions.apply(lambda c: math.sqrt(sklearn.metrics.mean_squared_error(cluster0_predictions.actual_logerror, c)))
# Out:
# actual_logerror                                                 0.000
# baseline_logerror                                               0.021
# logerror ~ price_per_sq_ft + buildingqualitytypeid + tax_rate   0.021
# logerror ~ calculatedfinishedsquarefeet + lotsizesquarefeet     0.021
# dtype: float64

# %% [markdown]
# > Our baseline RMSE and model RMSE for logerror are the same.

# %%
ev.better_than_baseline(cluster0_predictions.actual_logerror, cluster0_predictions["logerror ~ calculatedfinishedsquarefeet + lotsizesquarefeet"], cluster0_predictions.baseline_logerror, cluster0_predictions)
# Out:
# Model performs better than baseline

# %% [markdown]
# > According to our better_than_baseline function, our model is performing better than the baseline.

# %%
plt.figure(figsize=(16, 8))
sns.regplot(x=cluster0_predictions.actual_logerror, y=cluster0_predictions["logerror ~ calculatedfinishedsquarefeet + lotsizesquarefeet"], data=cluster0_predictions, label="logerror ~ calculatedfinishedsquarefeet + lotsizesquarefeet", line_kws={"color": sns.color_palette("colorblind")[4]})
plt.ticklabel_format(axis="both", style="plain")

plt.title("Actual v. Predicted Logerror")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.legend()

plt.show()

# %% [markdown]
# ---
# ### size_cluster0 Model 3 - RFE

# %%
def run_dummies():
    for i in range(0, 7):
        df = train[train.size_cluster == i]
        k = 4
        X = df.drop(columns=["bathroomcnt", "fullbathcnt", "parcelid", "buildingqualitytypeid", "fips", "propertycountylandusecode", "regionidcity", "regionidcounty", "regionidzip", "unitcnt", "assessmentyear", "rawcensustractandblock", "censustractandblock", "transactiondate", "heatingorsystemdesc", "propertylandusedesc", "county", "logerror"])
        y = df.logerror
        lm = sklearn.linear_model.LinearRegression()
        rfe = RFE(lm, k)
        rfe.fit(X, y)
        X_rfe = rfe.transform(X)
        lm.fit(X_rfe, y)
    return y

# %% [raw]
# y = run_dummies()
# y

# %%
k = 4
lm = sklearn.linear_model.LinearRegression()

# %%
rfe = RFE(lm, k)
rfe.fit(X, y)
print(f'selected top {k} features:', X.columns[rfe.support_])

# %%
X_rfe = rfe.transform(X)
X_rfe

# %%
lm.fit(X_rfe, y)
cluster0_predictions['multiple_rfe'] = lm.predict(X_rfe)
cluster0_predictions

# %%
plt.figure(figsize=(16, 8))
ev.plot_residuals(cluster0_predictions.actual_logerror, cluster0_predictions.multiple_rfe)
plt.ticklabel_format(axis="both", style="plain")
plt.show()

# %%
print(f"""The equation of our regression line is: 
y = ({lm.coef_[0]:.2f} * {X.columns[rfe.support_][0]}) + ({lm.coef_[1]:.2f} * {X.columns[rfe.support_][1]}) + ({lm.coef_[2]:.2f} * {X.columns[rfe.support_][2]}) + ({lm.coef_[3]:.2f} * {X.columns[rfe.support_][3]}) + {lm.intercept_:.2f}""")

# %%
ev.regression_errors(cluster0_predictions.actual_logerror, cluster0_predictions.multiple_rfe, cluster0_predictions)

# %%
cluster0_predictions.apply(lambda c: math.sqrt(sklearn.metrics.mean_squared_error(cluster0_predictions.actual_logerror, c)))

# %% [markdown]
# > Our baseline RMSE and model RMSE for logerror are the same.

# %%
ev.better_than_baseline(cluster0_predictions.actual_logerror, cluster0_predictions.multiple_rfe, cluster0_predictions.baseline_logerror, cluster0_predictions)

# %% [markdown]
# > According to our better_than_baseline function, our model is performing better than the baseline.

# %%
plt.figure(figsize=(16, 8))
sns.regplot(x=cluster0_predictions.actual_logerror, y=cluster0_predictions.multiple_rfe, data=cluster0_predictions, label="multiple_rfe", line_kws={"color": sns.color_palette("colorblind")[4]})
plt.ticklabel_format(axis="both", style="plain")

plt.title("Actual v. Predicted Logerror")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.legend()

plt.show()
